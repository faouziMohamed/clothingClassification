# %%
(x,y),(x_,y_) = fashion_mnist.load_data()
x = x.reshape(-1,28,28,1)
x_ = x_.reshape(-1,28,28,1)
model.fit(x,y,epochs=5)

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
fashion_mnist = keras.datasets.fashion_mnist

# %%
import models as md
import dataset as dt

# %%
b = dt.Dtset(20000)
a = md.Model(hidden_neurones=1024 ,metrics=['accuracy'])
a.fit(b,batch_size=500,epochs=10)

model = a.model
# Out:
# Train on 40000 samples, validate on 20000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 139s 3ms/sample - loss: 1.8081 - accuracy: 0.6612 - val_loss: 1.6965 - val_accuracy: 0.7660
# Epoch 2/10
# 40000/40000 [==============================] - 116s 3ms/sample - loss: 1.6722 - accuracy: 0.7907 - val_loss: 1.6516 - val_accuracy: 0.8098
# Epoch 3/10
# 40000/40000 [==============================] - 114s 3ms/sample - loss: 1.6456 - accuracy: 0.8176 - val_loss: 1.6639 - val_accuracy: 0.7973
# Epoch 4/10
# 40000/40000 [==============================] - 107s 3ms/sample - loss: 1.6402 - accuracy: 0.8228 - val_loss: 1.6436 - val_accuracy: 0.8188
# Epoch 5/10
# 40000/40000 [==============================] - 109s 3ms/sample - loss: 1.6330 - accuracy: 0.8290 - val_loss: 1.6352 - val_accuracy: 0.8261
# Epoch 6/10
# 40000/40000 [==============================] - 116s 3ms/sample - loss: 1.6204 - accuracy: 0.8416 - val_loss: 1.6023 - val_accuracy: 0.8596
# Epoch 7/10
# 40000/40000 [==============================] - 116s 3ms/sample - loss: 1.5940 - accuracy: 0.8684 - val_loss: 1.5922 - val_accuracy: 0.8702
# Epoch 8/10
# 40000/40000 [==============================] - 116s 3ms/sample - loss: 1.5890 - accuracy: 0.8736 - val_loss: 1.5870 - val_accuracy: 0.8749
# Epoch 9/10
# 40000/40000 [==============================] - 118s 3ms/sample - loss: 1.5815 - accuracy: 0.8801 - val_loss: 1.5783 - val_accuracy: 0.8842
# Epoch 10/10
# 40000/40000 [==============================] - 115s 3ms/sample - loss: 1.5755 - accuracy: 0.8867 - val_loss: 1.5780 - val_accuracy: 0.8838

# %% [raw]
# model.save('model_appris_1_88%_jupyter_config_1.h5')

# %%
b.x_test = b.x_test.reshape(-1,28,28,1)
b.x_test[b.x_test == 255]
# Out:
# array([], dtype=float64)

# %%
model.evaluate(b.x_test,b.y_test)
# Out:
# 10000/10000 [==============================] - 21s 2ms/sample - loss: 1.5809 - accuracy: 0.8807
# [1.5809028566360475, 0.8807]

# %%
pred = model.predict(b.x_test)

# %%
label = 78
name = pred[label].argmax()
name_y = b.y_test[label]

name == name_y
# Out:
# True

# %%
model.get_config()
# Out:
# {'name': 'Sequential_Model_1',
#  'layers': [{'class_name': 'Conv2D',
#    'config': {'name': '1rs_Conv2D',
#     'trainable': True,
#     'batch_input_shape': (None, 28, 28, 1),
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'MaxPooling_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'Dropout_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Conv2D',
#    'config': {'name': '2nd_Conv2D',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'MaxPooling_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'Dropout_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.2,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Flatten',
#    'config': {'name': 'Flatten_Layer',
#     'trainable': True,
#     'dtype': 'float32',
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dense',
#    'config': {'name': '1st_dense_layer',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 1024,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dense',
#    'config': {'name': '2nd_dense_layer',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 10,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %%
model = keras.models.Sequential(
[
	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',input_shape=(28,28,1)),
	MaxPooling2D(2,2),
	Dropout(0.3),

	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
	MaxPooling2D(2,2),
	Dropout(0.3),
    
	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
	MaxPooling2D(2,2),
	Dropout(0.3),
    
	Flatten(),
	Dense(256,activation='relu'),
	Dense(10,activation='softmax')
])

model.compile(
            optimizer='adam',
            loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=['accuracy'])

# %%
f = np.ndarray([1,6])
type(f)

# %%
c = dt.Dtset()
c.x_validate.shape[0]

# %%
type(dt.Dtset())

# %%
a = dt.Dtset(4584)
b = dt.Dtset(20094)

# %%
model = keras.models.Sequential(
[
	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',input_shape=(images_width,images_height,1)),
	MaxPooling2D(2,2),
	Dropout(0.3),

	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
	MaxPooling2D(2,2),
	Dropout(0.3),
    
	Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu'),
	MaxPooling2D(2,2),
	Dropout(0.3),
    
	Flatten(),
	Dense(256,activation='relu'),
	Dense(10,activation='softmax')
])

# %%
model.fit(train_images,
		 train_labels,
		 batch_size=30,
		 epochs=10,
		 validation_data=(validate_images,validate_labels),
          verbose=1
		 )

# %%
model.reset_metrics()
# Save the model
model.save('model_PFE_mnist.h5')
model.save('model_PFE_mnist_tf.keras_python.h5', save_format='tf')

# %%
model = tf.keras.models.load_model('model_PFE_mnist.h5')

# %%
#Evaluate accuracy
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)

# %%
classifications = model.predict(test_images)
type(classifications)

# %%
test_images = test_images.reshape(test_images.shape[0], images_width, images_height)
label = 8452
name = test_labels[label]

#Getting the predicted value 
print(f'Probabities of the {label}th element : \n{classifications[label]}')
name_predicted = classifications[label].argmax()

#Test 
print(f'\nThis {label}th element is probably : {class_names_fr[name_predicted]}')
print(f'This prediction is {class_names_fr[name_predicted] == class_names_fr[name]}') #Shows if the prediction is true or false

# %%
def plot_prediction(index_test, prediction_result):
  if type(index_test) is not int:
    raise ValueError(f"""Error '{index_test}' is not an integer, aborting...""")
  try:
    label = int(index_test)
    name = test_labels[label]
    
    classifications = prediction_result
    name_predicted = classifications[label].argmax()
  except IndexError:
    quit()
  except ValueError:
    raise ValueError(f"""Value error or the model is not correct! Aborting...""")

  #Drawing the two images
  plt.figure(figsize=(6,6))

  #The image of test
  plt.subplot(1,2,1)
  plt.imshow(test_images[label])
  plt.title(class_names_fr[name])

  #Predicted image
  plt.subplot(1,2,2)
  plt.imshow(test_images[label])

  if class_names_fr[name_predicted] == class_names_fr[name]:
    plt.title(class_names_fr[name_predicted],c='blue')
  else:
    plt.title(class_names_fr[name_predicted],c='red')
  #Drawing in the subplot
  plt.show()

# %%
for ii in range(898,900):
    plot_prediction(ii, classifications)

# %%
list(np.where(data == 25)[1])

# %%
def readImages(path):
    data = plt.imread(path)
    data[data>=255]
    return np.copy(data[10::16,10::16,0])

p = readImages('/home/faouzi/Desktop/ff1.jpg')

# %%
#p = p.reshape(-1,28)
plt.imshow(p[:,:])
plt.show()
#p = p.reshape(-1,28,1)


ff = plt.imread('/home/faouzi/Desktop/ff1.jpg')
d = np.copy(ff[10::16,10::16,2])
d.shape

# %%
for i in range(100):
    if class_names_fr[test_labels[i]] == 'Manteau':
        print(f'index N° {i} : {class_names_fr[test_labels[i]]}')

# %%
p = p.reshape(-1,28)
test_images[6] = p

plot_prediction(6,classifications)
